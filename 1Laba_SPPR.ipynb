# %%
toys = [
    {"name": "Фигурка солдата", "parameters": {"Price": 120, "For Boys": True, "For Girls": False, "Requires Movement": True, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+" : False}},
    {"name": "Кукла", "parameters": {"Price": 100, "For Boys": False, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": False, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Машинка на пульте управления", "parameters": {"Price": 250, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": False, "Educational": False, "Electronic": True, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Пазлы", "parameters": {"Price": 50, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Конструктор", "parameters": {"Price": 200, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Мягкая игрушка", "parameters": {"Price": 250, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": False, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Настольная игра", "parameters": {"Price": 150,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": True}},
    {"name": "Игрушечный барабан", "parameters": {"Price": 100,"For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": False, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Пальчиковые краски", "parameters": {"Price": 80,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": True, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Блокнот для рисования", "parameters": {"Price": 50,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": True}},
    {"name": "Пузыри", "parameters": {"Price": 40, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": False, "Educational": False, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Игрушечный набор для кухни", "parameters": {"Price": 400,"For Boys": False, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Игрушечный набор доктора", "parameters": {"Price": 450, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Рация", "parameters": {"Price": 300, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": False, "Educational": False, "Electronic": True, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Игрушечный телефон", "parameters": {"Price": 200, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": True, "Multiplayer": False, "For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": False, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Игрушечный ноутбук", "parameters": {"Price": 250,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": True, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Меч", "parameters": {"Price": 350,"For Boys": True, "For Girls": False, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Камень-питомец", "parameters": {"Price": 20, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": True, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Железная дорога", "parameters": {"Price": 500, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": True, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Набор для магии", "parameters": {"Price": 400, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": True}},
    {"name": "Кубик-Рубика", "parameters": {"Price": 150, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": True}},
    {"name": "Фрисби", "parameters": {"Price": 250,"For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": False, "Educational": False, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": True}},
    {"name": "Йо-йо", "parameters": {"Price": 200,"For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Конструктор Марбл", "parameters": {"Price": 1000,"For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Игрушечный робот", "parameters": {"Price": 350, "For Boys": True, "For Girls": False, "Requires Movement": True, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": True, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Мяч", "parameters": {"Price": 100, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Телескоп", "parameters": {"Price": 600,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Тесто для игры", "parameters": {"Price": 150,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Воздушный змей", "parameters": {"Price": 250, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": False, "Educational": False, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Вертолет", "parameters": {"Price": 400,"For Boys": True, "For Girls": False, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": False, "Educational": False, "Electronic": True, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": False, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Игрушечный кассовый аппарат", "parameters": {"Price": 400, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": True, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Стетоскоп", "parameters": {"Price": 150,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Игрушечный Верстак", "parameters": {"Price": 500,"For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Лошадка-качалка", "parameters": {"Price": 1100, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": False, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Образовательный планшет", "parameters": {"Price": 300,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": True, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Раскраска", "parameters": {"Price": 100, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Мини-баскетбольное кольцо", "parameters": {"Price": 250, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": True, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Скакалка", "parameters": {"Price": 100,"For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": True, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": True}},
    {"name": "Игрушечный набор инструментов", "parameters": {"Price": 450,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Игрушечный бинокль", "parameters": {"Price": 500,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": True, "For Indoor Play": False, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Надувной бассейн", "parameters": {"Price": 1500,"For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": False, "Educational": False, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Трехколесный велосипед", "parameters": {"Price": 2500,"For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": False, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": False, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Водный пистолет", "parameters": {"Price": 250,"For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": False, "Educational": False, "Electronic": False, "Multiplayer": True, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Балансировочный велосипед", "parameters": {"Price": 2000,"For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": False, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Игрушечный микрофон", "parameters": {"Price": 500,"For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": True, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Набор для песочницы", "parameters": {"Price": 100,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": True, "For Indoor Play": False, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Мозаика", "parameters": {"Price": 250, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": True}},
    {"name": "Игрушечный микроскоп", "parameters": {"Price": 900, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Палатка-домик для игр", "parameters": {"Price": 1900, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Набор полицейского", "parameters": {"Price": 900, "For Boys": True, "For Girls": False, "Requires Movement": True, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Гоночная машинка", "parameters": {"Price": 440,"For Boys": True, "For Girls": False, "Requires Movement": True, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": True, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Алфавитные блоки", "parameters": {"Price": 300,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": False, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Игрушечные животные", "parameters": {"Price": 500, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Набор рыбака", "parameters": {"Price": 500, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": False, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Игрушечный трактор", "parameters": {"Price": 400, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Билеты банка приколов", "parameters": {"Price": 50,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": True, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Набор для выживания", "parameters": {"Price": 450,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": True, "For Indoor Play": False, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Фигурка бродяги", "parameters": {"Price": 250, "For Boys": False, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": False, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Фигурка кассира", "parameters": {"Price": 250, "For Boys": False, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": True, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Игрушечная газонокосилка", "parameters": {"Price": 700, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": True, "Educational": False, "Electronic": True, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Замок", "parameters": {"Price": 1000, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Игрушечный молоток", "parameters": {"Price": 250, "For Boys": True, "For Girls": False, "Requires Movement": True, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Игрушечные ножницы", "parameters": {"Price": 250, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Набор ученого", "parameters": {"Price": 500, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": True}},
    {"name": "Электрическая железная дорога", "parameters": {"Price": 1550, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": False, "For Indoor Play": True, "Educational": False, "Electronic": True, "Multiplayer": True, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Большой робот", "parameters": {"Price": 1000,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": True, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Набор химика", "parameters": {"Price": 800,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": False, "Age Range 9-12": True, "Age Range 13+": True}},
    {"name": "Самолет с дистанционным управлением", "parameters": {"Price": 1700, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": False, "Educational": False, "Electronic": True, "Multiplayer": True, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Декорации для кукольного театра", "parameters": {"Price": 250, "For Boys": False, "For Girls": True, "Requires Movement": True, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": False, "Age Range 13+": False}},
    {"name": "Набор шаров", "parameters": {"Price": 200,"For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": True, "For One Person": False, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": False}},
    {"name": "Художественный мольберт", "parameters": {"Price": 400, "For Boys": True, "For Girls": True, "Requires Movement": False, "For Outdoor Play": False, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": False, "For One Person": True, "Age Range 0-2": False, "Age Range 3-5": False, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": True}},
    {"name": "Конструктор", "parameters": { "Price": 150, "For Boys": True, "For Girls": True, "Requires Movement": True, "For Outdoor Play": True, "For Indoor Play": True, "Educational": True, "Electronic": False, "Multiplayer": True,"For One Person": True, "Age Range 0-2": True, "Age Range 3-5": True, "Age Range 6-8": True, "Age Range 9-12": True, "Age Range 13+": True}},
    {"name": "Плюшевый мишкa","parameters": {"Price": 80,"For Boys": True,"For Girls": True,"Requires Movement": False,"For Outdoor Play": False,"For Indoor Play": True,"Educational": False,"Electronic": False,"Multiplayer": False,"For One Person": True,"Age Range 0-2": True,"Age Range 3-5": True,"Age Range 6-8": True,"Age Range 9-12": False,"Age Range 13+": False}},
    {"name": "Набор для творчества","parameters": {"Price": 200,"For Boys": True,"For Girls": True,"Requires Movement": False,"For Outdoor Play": True,"For Indoor Play": True,"Educational": True,"Electronic": False,"Multiplayer": True,"For One Person": True,"Age Range 0-2": False,"Age Range 3-5": True,"Age Range 6-8": True,"Age Range 9-12": True,"Age Range 13+": False}},
    {"name": "Настoльная игра","parameters": {"Price": 300,"For Boys": True,"For Girls": True,"Requires Movement": True,"For Outdoor Play": False,"For Indoor Play": True,"Educational": False,"Electronic": False,"Multiplayer": True,"For One Person": False,"Age Range 0-2": False,"Age Range 3-5": True,"Age Range 6-8": True,"Age Range 9-12": True,"Age Range 13+": True}},
    {"name": "Спoртивный мяч","parameters": {"Price": 100,"For Boys": True,"For Girls": True,"Requires Movement": True,"For Outdoor Play": True,"For Indoor Play": True,"Educational": False,"Electronic": False,"Multiplayer": True,"For One Person": False,"Age Range 0-2": False,"Age Range 3-5": True,"Age Range 6-8": True,"Age Range 9-12": True,"Age Range 13+": False}},
    {"name": "Робот-игрушка","parameters": {"Price": 400,"For Boys": True,"For Girls": True,"Requires Movement": True,"For Outdoor Play": True,"For Indoor Play": True,"Educational": True,"Electronic": True,"Multiplayer": False,"For One Person": True,"Age Range 0-2": True,"Age Range 3-5": True,"Age Range 6-8": True,"Age Range 9-12": True,"Age Range 13+": False}},
    {"name": "Huddy",  "parameters": {"Price": 500,"For Boys": True,"For Girls": True,"Requires Movement": True,"For Outdoor Play": True,"For Indoor Play": True,"Educational": False,"Electronic": True,"Multiplayer": True,"For One Person": True,"Age Range 0-2": False,"Age Range 3-5": True,"Age Range 6-8": True,"Age Range 9-12": True,"Age Range 13+": True}},
    {"name": "Кубики 2","parameters": {"Price": 70,"For Boys": True,"For Girls": True,"Requires Movement": False,"For Outdoor Play": False,"For Indoor Play": True,"Educational": True,"Electronic": False,"Multiplayer": False,"For One Person": True,"Age Range 0-2": True,"Age Range 3-5": True,"Age Range 6-8": True,"Age Range 9-12": False,"Age Range 13+": False}},
    {"name": "Игроваяя палатка","parameters": {"Price": 220,"For Boys": True,"For Girls": True,"Requires Movement": True,"For Outdoor Play": True,"For Indoor Play": True,"Educational": False,"Electronic": False,"Multiplayer": True,"For One Person": False,"Age Range 0-2": True,"Age Range 3-5": True,"Age Range 6-8": True,"Age Range 9-12": False,"Age Range 13+": False}},
    {"name": "Магнитная дoска","parameters": {"Price": 250,"For Boys": True,"For Girls": True,"Requires Movement": False,"For Outdoor Play": False,"For Indoor Play": True,"Educational": True,"Electronic": False,"Multiplayer": False,"For One Person": True,"Age Range 0-2": False,"Age Range 3-5": True,"Age Range 6-8": True,"Age Range 9-12": True,"Age Range 13+": False}},
    {"name": "Легo","parameters": {"Price": 300,"For Boys": True,"For Girls": True,"Requires Movement": True,"For Outdoor Play": True,"For Indoor Play": True,"Educational": True,"Electronic": False,"Multiplayer": True,"For One Person": True,"Age Range 0-2": True,"Age Range 3-5": True,"Age Range 6-8": True,"Age Range 9-12": True,"Age Range 13+": False}}
]

# %%
import pandas as pd

# %%
toys_data = []
for toy in toys:
    toy_name = toy["name"]
    toy_params = toy["parameters"]
    toy_entry = {"Toy Name": toy_name, **toy_params}
    toys_data.append(toy_entry)

# %%
df = pd.DataFrame(toys_data)

# %%
df.to_csv('toys_database1.csv', index=False)

# %%
df
# Out:
#                         Toy Name  Price  For Boys  For Girls  \
# 0                Фигурка солдата    120      True      False
# 1                          Кукла    100     False       True
# 2   Машинка на пульте управления    250      True       True
# 3                          Пазлы     50      True       True
# 4                    Конструктор    200      True       True
# ..                           ...    ...       ...        ...
# 77                         Huddy    500      True       True
# 78                      Кубики 2     70      True       True
# 79              Игроваяя палатка    220      True       True
# 80               Магнитная дoска    250      True       True
# 81                          Легo    300      True       True
#
#     Requires Movement  For Outdoor Play  For Indoor Play  Educational  \
# 0                True             False             True        False
# 1               False             False             True        False
# ...
